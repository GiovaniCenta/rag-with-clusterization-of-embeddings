# %% [markdown]
# # Clusterization test in books
# ### Objective: Test the formation of clusters in bigger documents (books) and then ask a question to identify the best cluster.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
import os
import pandas as pd
import openai
from dotenv import load_dotenv
import PyPDF2  # Import PyPDF2

# Load environment variables
load_dotenv()

def extract_text_from_pdf(pdf_path,num_paginas = 100):
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        pages_text = []
        for page_num in range(min(num_paginas, len(reader.pages))):  # Extract from the first num_paginas pages or total pages if less than 100
            page = reader.pages[page_num]
            page_text = page.extract_text() if page.extract_text() else ''  # Extract text or return empty string if None
            pages_text.append(page_text)
    return pages_text

def split_into_chunks(pages_text, chunk_size):
    chunks = []  # To hold chunks of concatenated page texts
    page_ranges = []  # To hold corresponding page ranges for each chunk

    current_chunk = ''  # Accumulates text for the current chunk
    chunk_start_page = 0  # Tracks the start page index of the current chunk
    for i, page_text in enumerate(pages_text):
        # Check if the current page fits into the current chunk
        if len(current_chunk) + len(page_text) <= chunk_size:
            # Add the page text to the chunk
            current_chunk += page_text
            # If it's the last page, close off the current chunk
            if i == len(pages_text) - 1:
                chunks.append(current_chunk)
                page_ranges.append((chunk_start_page, i))
        else:
            # If the current chunk is not empty, save it before starting a new one
            if current_chunk:
                chunks.append(current_chunk)
                page_ranges.append((chunk_start_page, i - 1))
            # Start a new chunk with the current page
            # But if the page itself exceeds the chunk size, handle it specially
            if len(page_text) > chunk_size:
                # Break down the large page into subchunks, if necessary
                for start in range(0, len(page_text), chunk_size):
                    end = start + chunk_size
                    chunks.append(page_text[start:end])
                    page_ranges.append((i, i))  # This subchunk still corresponds to the current page
                current_chunk = ''  # Reset for the next chunk after handling large page
                chunk_start_page = i + 1  # Next chunk will start from the following page
            else:
                # Otherwise, just start the new chunk normally
                current_chunk = page_text
                chunk_start_page = i
            # Handle case where this is the last page and its text hasn't been added to chunks
            if i == len(pages_text) - 1 and len(page_text) <= chunk_size:
                chunks.append(current_chunk)
                page_ranges.append((chunk_start_page, i))

    return chunks, page_ranges




def generate_embeddings_openai(text, openai_api_key=os.getenv('OPEN_AI_API_KEY')):
    openai.api_key = openai_api_key
    try:
        response = openai.Embedding.create(
            input=text,  # Ensure 'input' is correct according to the OpenAI API documentation
            model="text-embedding-ada-002"
        )
        embedding_list = response['data'][0]['embedding']
        return embedding_list
    except Exception as e:
        print(f"An error occurred: {e}")
        return []  # Return an empty list if there's an error

# Function to create the dataset
def create_dataset(book_paths, chunk_size=1000,num_paginas = 100):
    rows = []
    
    for book_path in book_paths:
        print(f"Processing {book_path}")
        pages_text = extract_text_from_pdf(book_path,num_paginas)
        chunks, page_ranges = split_into_chunks(pages_text, chunk_size)
        
        for chunk, (start_page, end_page) in zip(chunks, page_ranges):
            embedding = generate_embeddings_openai(chunk)
            rows.append({
                'document_name': os.path.basename(book_path),
                'chunk_text': chunk,
                'init_page': start_page + 1,  # Adding 1 to make page numbers human-readable
                'end_page': end_page + 1,    # Adding 1 to make page numbers human-readable
                'embedding': embedding
            })
    
    return pd.DataFrame(rows)

# List of your book paths
book_paths = [
    'livros/Harry Potter e a Pedra Filosofal.pdf',
    'livros/Harry Potter e a Câmara Secreta.pdf',
    'livros/Harry Potter e o prisioneiro de Azkaban.pdf',
    'livros/harry potter e a pedra filosofal.pdf',
    'livros/Harry Potter e o Cálice de Fogo.pdf',
    'livros/Harry Potter e a Ordem da Fênix.pdf',
    'livros/Harry Potter e o Enigma do Príncipe.pdf',
    'livros/Harry Potter e as Relíquias da Morte.pdf'    
]

# %%
# Create the dataset
dataset = create_dataset(book_paths)

# Save to CSV
dataset.to_csv('hp_data_set_1000.csv', index=False)
# Out:
# Processing livros/Harry Potter e a Pedra Filosofal.pdf
# Processing livros/Harry Potter e a Câmara Secreta.pdf
# Processing livros/Harry Potter e o prisioneiro de Azkaban.pdf
# Processing livros/harry potter e a pedra filosofal.pdf
# Processing livros/Harry Potter e o Cálice de Fogo.pdf
# Processing livros/Harry Potter e a Ordem da Fênix.pdf
# Processing livros/Harry Potter e o Enigma do Príncipe.pdf
# Processing livros/Harry Potter e as Relíquias da Morte.pdf

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import plotly.graph_objects as go

# Load the dataset
def embbed_and_plot(df):
    df['embedding'] = df['embedding'].apply(lambda x: eval(x))  # Convert stringified lists back to Python lists
    df['first_15_words'] = df['chunk_text'].apply(lambda x: ' '.join(str(x).split()[:15]))

    # Convert list of embeddings into a 2D numpy array and scale
    X = np.array(df['embedding'].tolist())
    scaler = StandardScaler().fit(X)  # Fit scaler to the data
    X_scaled = scaler.transform(X)  # Apply scaling

    # Perform PCA to reduce the embeddings to 2 dimensions
    pca = PCA(n_components=2)
    principalComponents = pca.fit_transform(X_scaled)  # Apply PCA to scaled data

    # Add the principal components back to the dataframe
    df['principal component 1'] = principalComponents[:, 0]
    df['principal component 2'] = principalComponents[:, 1]

    # Plot initialization
    fig = go.Figure()
    colors = {
        'Harry Potter e a Pedra Filosofal.pdf': 'red',
        'Harry Potter e a Câmara Secreta.pdf': 'green',
        'Harry Potter e o prisioneiro de Azkaban.pdf': 'blue',
        'Harry Potter e o Cálice de Fogo.pdf': 'yellow',
        'Harry Potter e a Ordem da Fênix.pdf': 'cyan',
        'Harry Potter e o Enigma do Príncipe.pdf': 'magenta',
        'Harry Potter e as Relíquias da Morte.pdf': 'grey'
    }
    centroids = {}

    # Add traces for each book
    for book, color in colors.items():
        book_df = df[df['document_name'] == book]
        fig.add_trace(go.Scatter(
            x=book_df['principal component 1'], 
            y=book_df['principal component 2'],
            text=book_df['first_15_words'],  # Display on hover
            mode='markers',
            marker_color=color,
            name=book
        ))
        book_df = df[df['document_name'] == book]
        centroid = book_df[['principal component 1', 'principal component 2']].mean().values
        centroids[book] = centroid  # Store the centroid
        fig.add_trace(go.Scatter(
            x=[centroid[0]], 
            y=[centroid[1]],
            text=[book],  # Book name for centroid hover
            mode='markers+text',
            marker_symbol='x',
            marker_size=12,
            marker_color='black',
            showlegend=False,
            textposition="top center"
        ))

    # Customize layout
    fig.update_layout(
        title='PCA of Book Embeddings with Centroids',
        xaxis_title='Principal Component 1',
        yaxis_title='Principal Component 2',
        legend_title='Book Name'
    )

    # Show plot
    fig.show()
    
    return pca,df,fig,centroids,scaler

# %%
pca,df,fig,centroids,scaler = embbed_and_plot(pd.read_csv('hp_data_set_1000.csv'))

# %% [markdown]
# # 2 - Query

# %%
import os 
import openai
def generate_embeddings_openai(text, openai_api_key=os.getenv('OPEN_AI_API_KEY')):
    openai.api_key = openai_api_key
    response = openai.Embedding.create(
        input=text,
        model="text-embedding-ada-002"
    )
    embedding = response['data'][0]['embedding']
    return np.array(embedding)

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import plotly.express as px
import plotly.graph_objects as go

def query_and_plot(pca,fig,scaler,query_text = "harry você é um bruxo"):
    query_embedding = generate_embeddings_openai(query_text)  # Get embedding using OpenAI
    query_embedding_scaled = scaler.transform(np.array(query_embedding).reshape(1, -1))  # Scale using the same scaler
    query_pca = pca.transform(query_embedding_scaled)  # Apply PCA

    # Add the query to the plot for visualization
    fig.add_trace(go.Scatter(
        x=[query_pca[0, 0]], 
        y=[query_pca[0, 1]],
        text=query_text,  # Display the actual query text
        mode='markers+text',
        marker_symbol='star',  # Change marker symbol for better visibility
        marker_size=20,  # Increase marker size
        marker_color="lime",  # Use a bright color for visibility
        showlegend=False,
        textposition="top center",  # Adjust text position for clarity
        textfont=dict(  # Customize font properties for better visibility
            family="Arial, sans-serif",
            size=12,  # Increase text size
            color="blue",  # Choose a color that contrasts well with the marker color
        ),
    ))
    fig.show()
    return query_embedding,query_pca

# %%
query_embedding,query_pca = query_and_plot(pca,fig,scaler)

# %%
# Assuming your query's PCA coordinates are stored in query_pca

# Function to calculate Euclidean distance
def euclidean_distance(point1, point2):
    return np.sqrt(np.sum((np.array(point1) - np.array(point2)) ** 2))

def query_to_centroid_distances(query_pca, centroids):
    distances = {}
    for book, centroid in centroids.items():
        dist = euclidean_distance(query_pca, centroid)
        distances[book] = dist
    return distances

# %%
# Print the distances
distances = query_to_centroid_distances(query_pca, centroids)
for book, distance in sorted(distances.items(), key=lambda item: item[1]):
    print(f"Distance from query to centroid of '{book}': {distance}")
# Out:
# Distance from query to centroid of 'Harry Potter e o Enigma do Príncipe.pdf': 4.0465532563859545
# Distance from query to centroid of 'Harry Potter e o prisioneiro de Azkaban.pdf': 4.792477223510781
# Distance from query to centroid of 'Harry Potter e a Câmara Secreta.pdf': 5.138529289471549
# Distance from query to centroid of 'Harry Potter e a Ordem da Fênix.pdf': 19.074458224588508
# Distance from query to centroid of 'Harry Potter e a Pedra Filosofal.pdf': 20.13236855117465
# Distance from query to centroid of 'Harry Potter e o Cálice de Fogo.pdf': nan
# Distance from query to centroid of 'Harry Potter e as Relíquias da Morte.pdf': nan

# %% [markdown]
# # 3 - Similarity of chunk heuristic
#
# Heuristic for finding chunks:
#
# 1. Rank the distance from the query to the centroids of the documents.
#
# 2. Use a distance threshold:
#
#     2.a. If the distance threshold is exceeded, only use that centroid;
#
#     2.b. if it's lower, use all books within the threshold for comparison.

# %%
def find_closest_books(query_embedding, centroids, distance_threshold=30):
    distances = {}
    for book, centroid in centroids.items():
        dist = euclidean_distance(query_embedding, centroid)
        distances[book] = dist
    sorted_distances = sorted(distances.items(), key=lambda item: item[1])
    books_to_compare = [book for book, distance in sorted_distances if distance - sorted_distances[0][1] <= distance_threshold]
    return books_to_compare

# Find the closest books to the query

# %%
closest_books = find_closest_books(query_pca[0], centroids,30)
print(f"The closest books to the query are: {' ; '.join(closest_books)}")
# Out:
# The closest books to the query are: Harry Potter e o Enigma do Príncipe.pdf ; Harry Potter e o prisioneiro de Azkaban.pdf ; Harry Potter e a Câmara Secreta.pdf ; Harry Potter e a Ordem da Fênix.pdf ; Harry Potter e a Pedra Filosofal.pdf

# %%
from scipy.spatial.distance import cosine
import numpy as np

def compare_similarity(query_embedding, chunks, book_name):
    # Ensure the query embedding is a 1-D numpy array
    query_vec = np.array(query_embedding).flatten()
    
    # Dictionary to store similarities
    similarities = {}

    # Calculate cosine similarity for each chunk
    for index, row in chunks.iterrows():
        chunk_embedding = np.array(row['embedding']).flatten()  # Convert chunk embedding to 1-D numpy array
        # Compute cosine similarity (cosine returns the distance, so subtract from 1)
        cos_sim = 1 - cosine(query_vec, chunk_embedding)
        # Store the similarity along with chunk text and book name
        similarities[(row['chunk_text'], book_name)] = cos_sim

    return similarities

# %%
def find_best_chunk(query_embedding, closest_books, df):
    best_similarity = float('-inf')  # Initialize with the lowest similarity
    best_chunk_index = None  # To store the index of the best chunk

    for book in closest_books:
        book_chunks = df[df['document_name'] == book]
        # Calculate similarities for all chunks in the current book
        similarities = compare_similarity(query_embedding, book_chunks, book)
        
        # Find the best chunk for the current book
        for (chunk_text, _), cos_sim in similarities.items():
            if cos_sim > best_similarity:
                best_similarity = cos_sim
                # Find the index of the chunk with the best similarity
                best_chunk_index = book_chunks[book_chunks['chunk_text'] == chunk_text].index[0]

    # Retrieve the entire row for the best chunk using the index
    if best_chunk_index is not None:
        best_chunk_info = df.loc[best_chunk_index]
        return best_chunk_info, best_similarity
    else:
        return None, None  # In case no best chunk was found

# %%
best_chunk_info, best_similarity = find_best_chunk(query_embedding, closest_books, df)
clean_chunk_text = best_chunk_info['chunk_text'].replace('\t', ' ')

from termcolor import colored

header = colored(f"{'Best Chunk Info':^60}", 'blue', 'on_white', attrs=['bold'])  # Blue text on white background, bold
divider = colored('-' * 60, 'red')  # Red divider line

# Format each row with left alignment, ensuring each piece of info is neatly aligned, with different colors
similarity_row = colored(f"{'Best Similarity:':<20}", 'yellow') + str(best_similarity)
document_row = colored(f"{'Document Name:':<20}", 'green') + best_chunk_info['document_name']
text_row = colored(f"{'Chunk Text:':<20}", 'cyan') + clean_chunk_text + "..."
init_page_row = colored(f"{'Initial Page:':<20}", 'magenta') + str(best_chunk_info['init_page'])
end_page_row = colored(f"{'End Page:':<20}", 'magenta') + str(best_chunk_info['end_page'])

# Print each part of the table
print(header)
print(divider)
print(similarity_row)
print(document_row)
print(text_row)
print(init_page_row)
print(end_page_row)

#print(f"First 15 Words: {best_chunk_info['first_15_words']}")
#print(f"Principal Component 1: {best_chunk_info['principal component 1']:.6f}")
#print(f"Principal Component 2: {best_chunk_info['principal component 2']:.6f}")
# Out:
#                       Best Chunk Info
# ------------------------------------------------------------
# Best Similarity:    0.8774808917628497
# Document Name:      Harry Potter e a Câmara Secreta.pdf
# Chunk Text:         bruxo ou bruxa? Conseguiria até se alegrar com a visão do seu arqui-inimigo, Draco
# Malfoy, só para ter certeza de que tudo não passara de um sonho...
# Não que o ano todo em Hogwarts tivesse sido uma brincadeira. No finzinho do
# último trimestre, Harry se vira frente a frente com Lorde Voldemort em pessoa. O
# bruxo poderia ser um destroço do que fora, mas ainda inspirava terror, ainda era
# astuto, ainda estava decidido a retomar o poder. Harry escorregara por entre as
# garras de Voldemort uma segunda vez, mas fora por um triz, e mesmo agora, semanas
# depois, Harry continuava a acordar à noite, encharcado de suor frio, imaginando
# onde estaria Voldemort neste momento, lembrando-se do seu rosto lívido, dos seus
# olhos arregalados e delirantes...
# Harry endireitou-se de repente no banco do jardim. Estivera olhando
# distraidamente para a sebe –
# e a sebe estava olhando para ele
# . Dois enormes olhos
# verdes tinham aparecido entre as folhas.
# O garoto levantou-se de um salto no mesmo instante em que uma ...
# Initial Page:       14
# End Page:           14

# %%
import os

import csv
import json
from openai import OpenAI
client = OpenAI(api_key=os.getenv('OPEN_AI_API_KEY'))

# Load your API key from an environment variable or directly insert it here (not recommended for security reasons)



# Read the description from a text file
with open('assistant_description.txt', 'r', encoding='utf-8') as file:
    description_text = file.read()
    
print(description_text)
print(len(description_text))

# Convert your TSV data to the required JSONL format for the OpenAI file upload
with open('e.tsv', 'r', encoding='utf-8') as tsvfile, open('e.jsonl', 'w', encoding='utf-8') as jsonlfile:
    reader = csv.DictReader(tsvfile, delimiter='\t')
    for row in reader:
        json_line = {"prompt": row["original_text"], "completion": row["strong_text"]}
        jsonlfile.write(json.dumps(json_line) + '\n')

# Upload the file to OpenAI
file = client.files.create(
  file=open("e.jsonl", "rb"),
  purpose='fine-tune'
)

# Create an assistant using the OpenAI API with the uploaded file
assistant = client.beta.assistants.create(
  name="Data visualizer",
  description=description_text,
  model="gpt-4-turbo-preview"
  #tools=[{"type": "retrieval"}],
  #file_ids=[file.id]
)

# Print the ID of the newly created assistant
print(assistant.id)
# Out:
# siga estas regras:
# Apostos:Manter enumerativos e recapitulativos. Separar especificadores.
# Para Oracões:
# Relativas:Separar explicativas e restritivas.
# Adverbiais:Separar causais, comparativas, concessivas, consecutivas e finais. Manter condicionais e proporcionais. Inverter conformativas. Separar temporais.
# Coordenadas:Dividir assindéticas; fazer o mesmo para sindéticas conforme tipo.
# Reduzidas:Manter infinitivos, gerúndios, particípios.
# Voz Passiva: Converter para ativa.
# Use e.jsonl para exemplos
# 502
# asst_miJ3JEtjtUtHoWP7CYG07Fzm

# %%
thread = client.beta.threads.create()

# %%
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id,
  instructions="Crie um texto em portugues e resuma com o assistente"
)

# %%
import time
df = pd.read_csv('hp_data_set_1000.csv')
def simplify_text(text):
    # Initialize the assistant run (replace with your actual initialization code)
    run = client.beta.threads.runs.create(
        thread_id=thread.id,
        assistant_id=assistant.id,
        instructions="Simplifique esse texto usando o assistente"
        )
  
    # Check the run status and wait for completion
    while run.status in ['queued', 'in_progress', 'cancelling']:
        time.sleep(1)  # Wait for 1 second
        run = client.beta.threads.runs.retrieve(
            thread_id=thread.id,
            run_id=run.id
        )
  
    # If completed, retrieve the messages
    if run.status == 'completed':
        messages_response = client.beta.threads.messages.list(
            thread_id=thread.id
        )
        
        messages = client.beta.threads.messages.list(
        thread_id=thread.id
        )

        try:   
            assistant_response = messages.data[0].content[0].text.value
            return assistant_response
        except IndexError:
            return " "




# Apply the function to your DataFrame
df['simplified_text'] = df['chunk_text'].apply(simplify_text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[51], line 39
#      33             return " "
#      38 # Apply the function to your DataFrame
# ---> 39 df['simplified_text'] = df['chunk_text'].apply(simplify_text)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\series.py:4760, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4625 def apply(
#    4626     self,
#    4627     func: AggFuncType,
#    (...)
#    4632     **kwargs,
#    4633 ) -> DataFrame | Series:
#    4634     """
#    4635     Invoke function on values of Series.
#    4636
#    (...)
#    4751     dtype: float64
#    4752     """
#    4753     return SeriesApply(
#    4754         self,
#    4755         func,
#    4756         convert_dtype=convert_dtype,
#    4757         by_row=by_row,
#    4758         args=args,
#    4759         kwargs=kwargs,
# -> 4760     ).apply()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\apply.py:1207, in SeriesApply.apply(self)
#    1204     return self.apply_compat()
#    1206 # self.func is Callable
# -> 1207 return self.apply_standard()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\apply.py:1287, in SeriesApply.apply_standard(self)
#    1281 # row-wise access
#    1282 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1283 # we need to give `na_action="ignore"` for categorical data.
#    1284 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1285 #  Categorical (GH51645).
#    1286 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1287 mapped = obj._map_values(
#    1288     mapper=curried, na_action=action, convert=self.convert_dtype
#    1289 )
#    1291 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1292     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1293     #  See also GH#25959 regarding EA support
#    1294     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2917, in pandas._libs.lib.map_infer()
#
# Cell In[51], line 5, in simplify_text(text)
#       3 def simplify_text(text):
#       4     # Initialize the assistant run (replace with your actual initialization code)
# ----> 5     run = client.beta.threads.runs.create(
#       6         thread_id=thread.id,
#       7         assistant_id=assistant.id,
#       8         instructions="Simplifique esse texto usando o assistente"
#       9         )
#      11     # Check the run status and wait for completion
#      12     while run.status in ['queued', 'in_progress', 'cancelling']:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openai\_utils\_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openai\resources\beta\threads\runs\runs.py:276, in Runs.create(self, thread_id, assistant_id, additional_instructions, instructions, metadata, model, stream, tools, extra_headers, extra_query, extra_body, timeout)
#     274     raise ValueError(f"Expected a non-empty value for `thread_id` but received {thread_id!r}")
#     275 extra_headers = {"OpenAI-Beta": "assistants=v1", **(extra_headers or {})}
# --> 276 return self._post(
#     277     f"/threads/{thread_id}/runs",
#     278     body=maybe_transform(
#     279         {
#     280             "assistant_id": assistant_id,
#     281             "additional_instructions": additional_instructions,
#     282             "instructions": instructions,
#     283             "metadata": metadata,
#     284             "model": model,
#     285             "stream": stream,
#     286             "tools": tools,
#     287         },
#     288         run_create_params.RunCreateParams,
#     289     ),
#     290     options=make_request_options(
#     291         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     292     ),
#     293     cast_to=Run,
#     294     stream=stream or False,
#     295     stream_cls=Stream[AssistantStreamEvent],
#     296 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openai\_base_client.py:1208, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1194 def post(
#    1195     self,
#    1196     path: str,
#    (...)
#    1203     stream_cls: type[_StreamT] | None = None,
#    1204 ) -> ResponseT | _StreamT:
#    1205     opts = FinalRequestOptions.construct(
#    1206         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1207     )
# -> 1208     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openai\_base_client.py:897, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     888 def request(
#     889     self,
#     890     cast_to: Type[ResponseT],
#    (...)
#     895     stream_cls: type[_StreamT] | None = None,
#     896 ) -> ResponseT | _StreamT:
# --> 897     return self._request(
#     898         cast_to=cast_to,
#     899         options=options,
#     900         stream=stream,
#     901         stream_cls=stream_cls,
#     902         remaining_retries=remaining_retries,
#     903     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openai\_base_client.py:926, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     923     kwargs["auth"] = self.custom_auth
#     925 try:
# --> 926     response = self._client.send(
#     927         request,
#     928         stream=stream or self._should_stream_response_body(request=request),
#     929         **kwargs,
#     930     )
#     931 except httpx.TimeoutException as err:
#     932     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpx\_client.py:901, in Client.send(self, request, stream, auth, follow_redirects)
#     893 follow_redirects = (
#     894     self.follow_redirects
#     895     if isinstance(follow_redirects, UseClientDefault)
#     896     else follow_redirects
#     897 )
#     899 auth = self._build_request_auth(request, auth)
# --> 901 response = self._send_handling_auth(
#     902     request,
#     903     auth=auth,
#     904     follow_redirects=follow_redirects,
#     905     history=[],
#     906 )
#     907 try:
#     908     if not stream:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpx\_client.py:929, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     926 request = next(auth_flow)
#     928 while True:
# --> 929     response = self._send_handling_redirects(
#     930         request,
#     931         follow_redirects=follow_redirects,
#     932         history=history,
#     933     )
#     934     try:
#     935         try:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpx\_client.py:966, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     963 for hook in self._event_hooks["request"]:
#     964     hook(request)
# --> 966 response = self._send_single_request(request)
#     967 try:
#     968     for hook in self._event_hooks["response"]:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpx\_client.py:1002, in Client._send_single_request(self, request)
#     997     raise RuntimeError(
#     998         "Attempted to send an async request with a sync Client instance."
#     999     )
#    1001 with request_context(request=request):
# -> 1002     response = transport.handle_request(request)
#    1004 assert isinstance(response.stream, SyncByteStream)
#    1006 response.request = request
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpx\_transports\default.py:228, in HTTPTransport.handle_request(self, request)
#     215 req = httpcore.Request(
#     216     method=request.method,
#     217     url=httpcore.URL(
#    (...)
#     225     extensions=request.extensions,
#     226 )
#     227 with map_httpcore_exceptions():
# --> 228     resp = self._pool.handle_request(req)
#     230 assert isinstance(resp.stream, typing.Iterable)
#     232 return Response(
#     233     status_code=resp.status,
#     234     headers=resp.headers,
#     235     stream=ResponseStream(resp.stream),
#     236     extensions=resp.extensions,
#     237 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpcore\_sync\connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     266     with ShieldCancellation():
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#     270     break
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpcore\_sync\connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     248         raise exc
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#     260     with self._pool_lock:
#     261         # Maintain our position in the request queue, but reset the
#     262         # status so that the request becomes queued again.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     elif not self._connection.is_available():
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpcore\_sync\http11.py:133, in HTTP11Connection.handle_request(self, request)
#     131     with Trace("response_closed", logger, request) as trace:
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpcore\_sync\http11.py:111, in HTTP11Connection.handle_request(self, request)
#     101     pass
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#     119 return Response(
#     120     status=status,
#     121     headers=headers,
#    (...)
#     127     },
#     128 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpcore\_sync\http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     173 timeout = timeouts.get("read", None)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#     178         break
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpcore\_sync\http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     209     event = self._h11_state.next_event()
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#     224     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2288.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1295, in SSLSocket.recv(self, buflen, flags)
#    1291     if flags != 0:
#    1292         raise ValueError(
#    1293             "non-zero flags not allowed in calls to recv() on %s" %
#    1294             self.__class__)
# -> 1295     return self.read(buflen)
#    1296 else:
#    1297     return super().recv(buflen, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2288.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1168, in SSLSocket.read(self, len, buffer)
#    1166         return self._sslobj.read(len, buffer)
#    1167     else:
# -> 1168         return self._sslobj.read(len)
#    1169 except SSLError as x:
#    1170     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
df.to_csv('hp_data_set_1000_simplified.csv', index=False)

# %% [markdown]
# # 4 - Test with smaller chunks

# %%
dataset2 = create_dataset(book_paths,200)

# Save to CSV
dataset2.to_csv('hp_dataset_200.csv', index=False)
# Out:
# Processing livros/Harry Potter e a Pedra Filosofal.pdf
# Processing livros/Harry Potter e a Câmara Secreta.pdf
# Processing livros/Harry Potter e o prisioneiro de Azkaban.pdf
# Processing livros/harry potter e a pedra filosofal.pdf
# Processing livros/Harry Potter e o Cálice de Fogo.pdf
# Processing livros/Harry Potter e a Ordem da Fênix.pdf
# Processing livros/Harry Potter e o Enigma do Príncipe.pdf
# Processing livros/Harry Potter e as Relíquias da Morte.pdf

# %%
df,fig,centroids,scaler = embbed_and_plot(df  = pd.read_csv('hp_dataset_200.csv'))
# Out:
# Traceback (most recent call last):
#
#   File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\interactiveshell.py:3526 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[61], line 1
#     df,fig,centroids,scaler = embbed_and_plot(df  = pd.read_csv('hp_dataset_200.csv'))
#
#   Cell In[48], line 9 in embbed_and_plot
#     df['embedding'] = df['embedding'].apply(lambda x: eval(x))  # Convert stringified lists back to Python lists
#
#   File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\series.py:4760 in apply
#     ).apply()
#
#   File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\apply.py:1207 in apply
#     return self.apply_standard()
#
#   File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\apply.py:1287 in apply_standard
#     mapped = obj._map_values(
#
#   File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\base.py:921 in _map_values
#     return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
#   File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\algorithms.py:1814 in map_array
#     return lib.map_infer(values, mapper, convert=convert)
#
#   File lib.pyx:2917 in pandas._libs.lib.map_infer
#
#   Cell In[48], line 9 in <lambda>
#     df['embedding'] = df['embedding'].apply(lambda x: eval(x))  # Convert stringified lists back to Python lists
#
#   File <string>:1
#     [-0.00897342 -0.00681508 -0.01461563 ... -0.00496557  0.01072229
#      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
query_embedding,query_pca = query_and_plot(fig,scaler,query_text='harry você é um bruxo')

# %%
closest_books = find_closest_books(query_pca[0], centroids)
print(f"The closest books to the query are: {' ; '.join(closest_books)}")
# Out:
# The closest books to the query are: perdido em marte.pdf

# %%
best_chunk_info, best_similarity = find_best_chunk(query_embedding, closest_books, df)
clean_chunk_text = best_chunk_info['chunk_text'].replace('\t', ' ')

from termcolor import colored

header = colored(f"{'Best Chunk Info':^60}", 'blue', 'on_white', attrs=['bold'])  # Blue text on white background, bold
divider = colored('-' * 60, 'red')  # Red divider line

# Format each row with left alignment, ensuring each piece of info is neatly aligned, with different colors
similarity_row = colored(f"{'Best Similarity:':<20}", 'yellow') + str(best_similarity)
document_row = colored(f"{'Document Name:':<20}", 'green') + best_chunk_info['document_name']
text_row = colored(f"{'Chunk Text:':<20}", 'cyan') + clean_chunk_text + "..."
init_page_row = colored(f"{'Initial Page:':<20}", 'magenta') + str(best_chunk_info['init_page'])
end_page_row = colored(f"{'End Page:':<20}", 'magenta') + str(best_chunk_info['end_page'])

# Print each part of the table
print(header)
print(divider)
print(similarity_row)
print(document_row)
print(text_row)
print(init_page_row)
print(end_page_row)

#print(f"First 15 Words: {best_chunk_info['first_15_words']}")
#print(f"Principal Component 1: {best_chunk_info['principal component 1']:.6f}")
#print(f"Principal Component 2: {best_chunk_info['principal component 2']:.6f}")
# Out:
#                       Best Chunk Info
# ------------------------------------------------------------
# Best Similarity:    0.8626173606155557
# Document Name:      perdido em marte.pdf
# Chunk Text:         Marte não é desconhecido para mim. Estou aqui há muito tempo. Mas, até
# hoje, o Hab nunca havia ficado fora do meu campo de visão. Talvez você
# ache que isso não faz diferença, mas faz.
# À medida que eu avançava rumo ao local em que o GTR estava
# enterrado, me dei conta de que Marte é um deserto estéril e de que estou
# completamente
#  sozinho aqui. Eu já sabia disso, é claro. Mas existe uma
# diferença entre saber e de fato vivenciar algo. À minha volta, não há nada,
# apenas poeira, pedras e um deserto i...
# Initial Page:       72
# End Page:           72

# %% [markdown]
# # 5 - even smaller chunks

# %%
dataset=create_dataset(book_paths,chunk_size=1500,num_paginas = 100)
dataset.to_csv('hp_dataset_1500.csv', index=False)
# Out:
# Processing livros/Harry Potter e a Pedra Filosofal.pdf
# Processing livros/Harry Potter e a Câmara Secreta.pdf
# Processing livros/Harry Potter e o prisioneiro de Azkaban.pdf
# Processing livros/harry potter e a pedra filosofal.pdf
# Processing livros/Harry Potter e o Cálice de Fogo.pdf
# Processing livros/Harry Potter e a Ordem da Fênix.pdf
# Processing livros/Harry Potter e o Enigma do Príncipe.pdf
# Processing livros/Harry Potter e as Relíquias da Morte.pdf

# %%
df,fig,centroids,scaler = embbed_and_plot(df  = pd.read_csv('hp_data_set_1000.csv'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 df,fig,centroids,scaler = embbed_and_plot(df  = pd.read_csv('hp_data_set_1000.csv'))
#
# ValueError: too many values to unpack (expected 4)

# %%
query_embedding,query_pca = query_and_plot(fig,scaler)

# %%
closest_books = find_closest_books(query_pca[0], centroids)
print(f"The closest books to the query are: {' ; '.join(closest_books)}")

# %%
best_chunk_info, best_similarity = find_best_chunk(query_embedding, closest_books, df)
clean_chunk_text = best_chunk_info['chunk_text'].replace('\t', ' ')

from termcolor import colored

header = colored(f"{'Best Chunk Info':^60}", 'blue', 'on_white', attrs=['bold'])  # Blue text on white background, bold
divider = colored('-' * 60, 'red')  # Red divider line

# Format each row with left alignment, ensuring each piece of info is neatly aligned, with different colors
similarity_row = colored(f"{'Best Similarity:':<20}", 'yellow') + str(best_similarity)
document_row = colored(f"{'Document Name:':<20}", 'green') + best_chunk_info['document_name']
text_row = colored(f"{'Chunk Text:':<20}", 'cyan') + clean_chunk_text + "..."
init_page_row = colored(f"{'Initial Page:':<20}", 'magenta') + str(best_chunk_info['init_page'])
end_page_row = colored(f"{'End Page:':<20}", 'magenta') + str(best_chunk_info['end_page'])

# Print each part of the table
print(header)
print(divider)
print(similarity_row)
print(document_row)
print(text_row)
print(init_page_row)
print(end_page_row)

#print(f"First 15 Words: {best_chunk_info['first_15_words']}")
#print(f"Principal Component 1: {best_chunk_info['principal component 1']:.6f}")
#print(f"Principal Component 2: {best_chunk_info['principal component 2']:.6f}")

# %%
# !pip install hdbscan
# Out:
# Collecting hdbscan
#   Using cached hdbscan-0.8.33.tar.gz (5.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting cython<3,>=0.27 (from hdbscan)
#   Using cached Cython-0.29.37-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: numpy>=1.20 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from hdbscan) (1.24.3)
# Requirement already satisfied: scipy>=1.0 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from hdbscan) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.20 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from hdbscan) (1.3.2)
# Requirement already satisfied: joblib>=1.0 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from hdbscan) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn>=0.20->hdbscan) (3.2.0)
# Using cached Cython-0.29.37-py2.py3-none-any.whl (989 kB)
# Building wheels for collected packages: hdbscan
#   Building wheel for hdbscan (pyproject.toml): started
#   Building wheel for hdbscan (pyproject.toml): finished with status 'done'
#   Created wheel for hdbscan: filename=hdbscan-0.8.33-cp311-cp311-win_amd64.whl size=595848 sha256=3e85ea96574594c04f477bb719d65e93c375bc6e4b8d4d9350c3b9d56303a432
#   Stored in directory: c:\users\cliente\appdata\local\pip\cache\wheels\4e\8c\6f\d0495e4e40cbd27a8c7330d4e963837e099d6e16014dbdcdb5
# Successfully built hdbscan
# Installing collected packages: cython, hdbscan
# Successfully installed cython-0.29.37 hdbscan-0.8.33

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import plotly.graph_objects as go
import hdbscan  # Import HDBSCAN
import plotly.express as px
# Load the datasetimport pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import plotly.graph_objects as go
import hdbscan  # Make sure you have HDBSCAN installed

# Function to embed text and plot clusters
def embed_and_plot_hdb(df):
    df['embedding'] = df['embedding'].apply(lambda x: eval(x))  # Convert stringified lists back to Python lists
    df['first_15_words'] = df['chunk_text'].apply(lambda x: ' '.join(str(x).split()[:15]))

    # Convert list of embeddings into a 2D numpy array and scale
    X = np.array(df['embedding'].tolist())
    scaler = StandardScaler().fit(X)
    X_scaled = scaler.transform(X)

    # Perform PCA to reduce the embeddings to 2 dimensions
    pca = PCA(n_components=2)
    principalComponents = pca.fit_transform(X_scaled)

    # Add the principal components back to the dataframe
    df['principal component 1'] = principalComponents[:, 0]
    df['principal component 2'] = principalComponents[:, 1]

    # HDBSCAN Clustering
    clusterer = hdbscan.HDBSCAN(min_cluster_size=5, gen_min_span_tree=True)
    df['cluster'] = clusterer.fit_predict(principalComponents)

    # Plot initialization
    fig = go.Figure()

    # Define a color palette
    color_palette = px.colors.qualitative.Set1  # You can change this to other palettes
    
    # Assign a color to each cluster, including noise
    cluster_colors = {cluster: color_palette[i % len(color_palette)] for i, cluster in enumerate(sorted(df['cluster'].unique()))}

    # Use 'lightgrey' for noise points (cluster label -1)
    cluster_colors[-1] = 'lightgrey'

    # Add traces for each cluster
    for cluster in sorted(df['cluster'].unique()):
        cluster_df = df[df['cluster'] == cluster]
        fig.add_trace(go.Scatter(
            x=cluster_df['principal component 1'], 
            y=cluster_df['principal component 2'],
            text=cluster_df['first_15_words'],  # Display on hover
            mode='markers',
            marker=dict(
                color=cluster_colors[cluster],  # Use assigned color
                size=8,  # You can adjust the size as needed
                line=dict(width=1, color='DarkSlateGrey')  # Border for the markers
            ),
            name=f'Cluster {cluster if cluster != -1 else "Noise"}'
        ))

    # Customize layout
    fig.update_layout(
        title='PCA of Book Embeddings with HDBSCAN Clusters',
        xaxis_title='Principal Component 1',
        yaxis_title='Principal Component 2',
        legend_title='Cluster'
    )

    # Show plot
    fig.show()

    return pca, df, fig, clusterer, scaler

# %%
embed_and_plot_hdb(pd.read_csv('hp_data_set_1000.csv'))
# Out:
# (PCA(n_components=2),
#                                    document_name  \
#  0          Harry Potter e a Pedra Filosofal.pdf
#  1          Harry Potter e a Pedra Filosofal.pdf
#  2          Harry Potter e a Pedra Filosofal.pdf
#  3          Harry Potter e a Pedra Filosofal.pdf
#  4          Harry Potter e a Pedra Filosofal.pdf
#  ...                                         ...
#  2290  Harry Potter e as Relíquias da Morte.pdf
#  2291  Harry Potter e as Relíquias da Morte.pdf
#  2292  Harry Potter e as Relíquias da Morte.pdf
#  2293  Harry Potter e as Relíquias da Morte.pdf
#  2294  Harry Potter e as Relíquias da Morte.pdf
#
#                                               chunk_text  init_page  end_page  \
#  0     DADOS\tDE\tODINRIGHT\nSobre\ta\tobra:\nA\tpres...          2         2
#  1     conhecimento,\te\tnão\nmais\tlutando\tpor\tdin...          2         2
#  2     Converted\tby\t\nePubtoPDFDADOS\tDE\tCOPYRIGHT...          3         5
#  3     Título\tOriginal:\tHarry\tPotter\tand\tthe\tPh...          6         6
#  4     \t\nde\tJ.K.\tRowling\n\t\n\t\nContinue\tsua\t...          7         9
#  ...                                                 ...        ...       ...
#  2290  va nele, dispensou a garçonete. Ela o encarou ...         99        99
#  2291  tes cordas negras saíram da ponta de sua varin...         99        99
#  2292  – \nExpulso!\n – berrou o Comensal da Morte, e...        100       100
#  2293  u – disse. Ele virou o\ncorpo do Comensal mais...        100       100
#  2294  a deles. É melhor assim, despistaremos os dois...        100       100
#
#                                                embedding  \
#  0     [-0.0032466088887304068, -0.005156378727406263...
#  1     [-0.013343730010092258, -0.00846204161643982, ...
#  2     [0.0005724745569750667, 0.007305951789021492, ...
#  3     [0.008012066595256329, -0.017804590985178947, ...
#  4     [-0.008729209192097187, -0.0029351122211664915...
#  ...                                                 ...
#  2290  [-0.002915238495916128, -0.00787047017365694, ...
#  2291  [-0.008413358591496944, -0.00883469544351101, ...
#  2292  [-0.018024761229753494, 0.009608126245439053, ...
#  2293  [-0.001366342999972403, 0.004438276402652264, ...
#  2294  [-0.004959150683134794, 0.006940812338143587, ...
#
#                                           first_15_words  \
#  0     DADOS DE ODINRIGHT Sobre a obra: A presente ob...
#  1     conhecimento, e não mais lutando por dinheiro ...
#  2     Converted by ePubtoPDFDADOS DE COPYRIGHT Sobre...
#  3     Título Original: Harry Potter and the Philosop...
#  4     de J.K. Rowling Continue sua diversão com as h...
#  ...                                                 ...
#  2290  va nele, dispensou a garçonete. Ela o encarou ...
#  2291  tes cordas negras saíram da ponta de sua varin...
#  2292  – Expulso! – berrou o Comensal da Morte, e a m...
#  2293  u – disse. Ele virou o corpo do Comensal mais ...
#  2294  a deles. É melhor assim, despistaremos os dois...
#
#        principal component 1  principal component 2  cluster
#  0                 16.899394               7.123577       -1
#  1                 16.765079              10.285560       -1
#  2                 20.143836               7.408758       -1
#  3                 -3.586735               0.844355       35
#  4                  1.052445              -4.398271       -1
#  ...                     ...                    ...      ...
#  2290              -8.550088               2.061347       35
#  2291              -3.906510               8.313794       -1
#  2292              -9.387782               1.994943       35
#  2293             -10.754136              -1.305569       35
#  2294              -8.884902               2.831710       35
#
#  [2295 rows x 9 columns],
#  Figure({
#      'data': [{'marker': {'color': 'lightgrey', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster Noise',
#                'text': array(['DADOS DE ODINRIGHT Sobre a obra: A presente obra é disponibilizada pela equipe eLivros e',
#                               'conhecimento, e não mais lutando por dinheiro e poder, então nossa sociedade poderá enfim evoluir',
#                               'Converted by ePubtoPDFDADOS DE COPYRIGHT Sobre a obra: A presente obra é disponibilizada pela equipe',
#                               ...,
#                               'mbro de ocasião mais desesperadamente triste. Alvo estava com o coração despedaçado... – E não',
#                               'acioso e reluzente, o lince aterrissou com leveza entre os espantados convidados. Cabeças se viraram,',
#                               'tes cordas negras saíram da ponta de sua varinha e amarraram o garoto da cabeça'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([16.89939372, 16.7650792 , 20.14383553, ..., -1.36832115, -0.15449831,
#                            -3.90650958]),
#                'y': array([ 7.1235771 , 10.2855602 ,  7.40875764, ..., 11.12464998, 13.59174992,
#                             8.31379429])},
#               {'marker': {'color': 'rgb(55,126,184)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 0',
#                'text': array(['mo uma estátua, os olhos fixos na esquina mais distante da rua dos Alfeneiros. E',
#                               'mais enquanto eles olhavam para cima e para baixo da rua à procura de um',
#                               'm viu como foi: num segundo, Pedro e Duda estavam encostados no vidro, no segundo',
#                               'ou algumas vezes e então fez força para produzir um sorriso que pareceu bem',
#                               'u pai e minha mãe eram famosos?',
#                               'e ficar com ele. Não se assuste se ele se mexer um pouco, acho que',
#                               ', que esperara mais mármore, surpreendeu-se. Encontravam-se em uma passagem estreita de pedra, iluminada por',
#                               'mo uma estátua, os olhos fixos na esquina mais distante da rua dos Alfeneiros. E',
#                               'mais enquanto eles olhavam para cima e para baixo da rua à procura de um',
#                               'm viu como foi: num segundo, Pedro e Duda estavam encostados no vidro, no segundo',
#                               'ou algumas vezes e então fez força para produzir um sorriso que pareceu bem',
#                               'u pai e minha mãe eram famosos?',
#                               'e ficar com ele. Não se assuste se ele se mexer um pouco, acho que',
#                               ', que esperara mais mármore, surpreendeu-se. Encontravam-se em uma passagem estreita de pedra, iluminada por',
#                               '— CAPÍTULO VINTE E TRÊS — — CAPÍTULO VINTE E QUATRO — — CAPÍTULO VINTE',
#                               'ago revirou. Talvez aquela noite – depois de um mês de espera – fosse a',
#                               'em produzira o estampido. – Fazer um barulho desses como se fosse um tiro de',
#                               'pelo aposento fechado. – Lembre-se da última, Petúnia. Petúnia pareceu que ia desmaiar. Afundou na',
#                               'erto, quando ela reabriu os olhos. – Sou metamorfomaga – respondeu ela, voltando a olhar',
#                               'ão sei… ele achava que não era suficiente.',
#                               'dando-as no bolso. – Mas ainda é preciso um pouco de pesquisa. No momento, os',
#                               'de vapor e não para mais. E anda doida para ter uma chance de desancar'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([20.49536141, 19.82693853, 21.97702745, 20.90557934, 21.3353466 ,
#                            20.14153651, 20.30709398, 20.49536141, 19.82693853, 21.97702745,
#                            20.90557934, 21.3353466 , 20.16553903, 20.30709398, 19.2083242 ,
#                            20.21161607, 21.7291266 , 22.02220598, 17.89395896, 19.53130341,
#                            20.87833454, 19.09731907]),
#                'y': array([3.36359015, 5.05614079, 3.2437952 , 4.47878628, 5.76752218, 2.58418858,
#                            4.64711431, 3.36359015, 5.05614079, 3.2437952 , 4.47878628, 5.76752218,
#                            2.49473137, 4.64711431, 2.84286913, 3.60486299, 2.44457968, 3.78487423,
#                            2.78069767, 3.59455499, 2.82740014, 3.5921805 ])},
#               {'marker': {'color': 'rgb(77,175,74)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 1',
#                'text': array(['Eles viajaram no carro. E viajaram. Nem tia Petúnia se atrevia a perguntar aonde iam.',
#                               'Começou a chover. Grandes gotas batiam no teto do carro. Duda choramingou. – É segunda-feira',
#                               'isquer meios Para atingir os fins que antes colimaram. Vamos, me experimentem! Não devem temer!',
#                               'Eles viajaram no carro. E viajaram. Nem tia Petúnia se atrevia a perguntar aonde iam.',
#                               'Começou a chover. Grandes gotas batiam no teto do carro. Duda choramingou. – É segunda-feira',
#                               'isquer meios Para atingir os fins que antes colimaram. Vamos, me experimentem! Não devem temer!',
#                               'ez a ser expulso. As vozes dos companheiros de Duda foram morrendo, eles tinham desaparecido'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([19.17111332, 19.88653894, 18.92992849, 19.17111332, 19.88653894,
#                            18.92992849, 19.36829909]),
#                'y': array([-3.74440287, -2.54712956, -2.34263383, -3.74440287, -2.54712956,
#                            -2.34263383, -2.29381071])},
#               {'marker': {'color': 'rgb(152,78,163)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 2',
#                'text': array(['estavam mais escutando. – Talvez pudéssemos levá-lo ao zoológico – disse tia Petúnia lentamente –',
#                               'ntos para sair. Vamos viajar. Ponham apenas algumas roupas nas malas. Não quero discussão! Ele',
#                               'so. – Desculpem, mas vocês viram um sapo? Quando os dois sacudiram a cabeça, ele',
#                               'estavam mais escutando. – Talvez pudéssemos levá-lo ao zoológico – disse tia Petúnia lentamente –',
#                               'ntos para sair. Vamos viajar. Ponham apenas algumas roupas nas malas. Não quero discussão! Ele',
#                               'so. – Desculpem, mas vocês viram um sapo? Quando os dois sacudiram a cabeça, ele',
#                               'lado de fora, no canteiro, o estômago do garoto pareceu se descontrair. Se tivesse acontecido'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([20.16479123, 19.84866612, 18.99668381, 20.16479123, 19.84866612,
#                            18.99668381, 19.16323891]),
#                'y': array([ 0.54941782,  0.63045975,  0.2805823 ,  0.54941782,  0.63045975,
#                             0.2805823 , -0.2778174 ])},
#               {'marker': {'color': 'rgb(255,127,0)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 3',
#                'text': array(['inta... trinta... – Trinta e nove, anjinho – disse tia Petúnia. – Ah. – Duda',
#                               '. Duda logo encontrou a maior cobra que havia. Poderia dar duas voltas no carro',
#                               'terão de desistir. – Não tenho muita certeza de que isto vai dar certo, Válter.',
#                               'havia o casebre mais miserável que se pode imaginar. Uma coisa era certa, ali não',
#                               'inta... trinta... – Trinta e nove, anjinho – disse tia Petúnia. – Ah. – Duda',
#                               '. Duda logo encontrou a maior cobra que havia. Poderia dar duas voltas no carro',
#                               'terão de desistir. – Não tenho muita certeza de que isto vai dar certo, Válter.',
#                               'havia o casebre mais miserável que se pode imaginar. Uma coisa era certa, ali não'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([21.10463412, 20.38608982, 21.51910769, 22.233406  , 21.10463412,
#                            20.38608982, 21.51910769, 22.233406  ]),
#                'y': array([-1.65607125, -0.78092001, -1.09593767, -1.64148388, -1.65607125,
#                            -0.78092001, -1.09593767, -1.64148388])},
#               {'marker': {'color': 'rgb(255,255,51)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 4',
#                'text': array(['A fumaça da locomotiva se dispersava sobre as cabeças das pessoas que conversavam, enquanto gatos',
#                               'sacudiu os ombros. – Mas vamos ter que nos cuidar daqui para a frente –',
#                               'ido –, você vai ter que dar o fora por uma semana. Vá com Errol.',
#                               '– Quem ficou cuidando dos outros cachorros, Guida? – perguntou tio Válter. – Ah, deixei',
#                               'versa atentamente. – Não muito longe daqui – respondeu o colega, que parecia excitado. –',
#                               'do nos prejudicar! Precisamos ganhar! – Olívio, vê se se acalma! – disse Fred, ligeiramente',
#                               'A fumaça da locomotiva se dispersava sobre as cabeças das pessoas que conversavam, enquanto gatos',
#                               'Conteúdo — CAPÍTULO UM — — CAPÍTULO DOIS — — CAPÍTULO TRÊS — — CAPÍTULO',
#                               'nfelizmente, não satisfaz nenhum dos dois requisitos. – Eu o encontrei – disse Rabicho, e',
#                               'Duda era um menino muito talentoso, incompreendido pelos professores, enquanto tio Válter sustentava que “ele',
#                               'unidade. V. Sª deverá, portanto, considerar-se suspenso da escola até o término das investigações. Com',
#                               'ecido por agir impulsivamente, Sirius,',
#                               'Conteúdo — CAPÍTULO UM — — CAPÍTULO DOIS — — CAPÍTULO TRÊS — — CAPÍTULO',
#                               'Conteúdo — CAPÍTULO UM — — CAPÍTULO DOIS — — CAPÍTULO TRÊS — — CAPÍTULO'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([14.05156888, 10.01625108, 11.34329593, 12.89399247, 13.09656595,
#                            12.6954584 , 14.05156888, 12.8671055 , 12.26377196, 12.73582785,
#                            13.47243835, 12.48479703, 12.73155861, 12.58958706]),
#                'y': array([ 8.67091556,  9.85977798, 10.58916433, 11.19725636, 12.13177068,
#                            11.05602038,  8.67091556, 10.69559632, 10.07116656,  9.15430893,
#                             9.41135058,  8.56307069, 11.08394161, 10.77515624])},
#               {'marker': {'color': 'rgb(166,86,40)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 5',
#                'text': array(['noticiário noturno. “E, por último, os observadores de pássaros em toda parte registraram que as',
#                               '— CAPÍTULO QUATRO — O guardião das chaves B um. Bateram outra vez. Duda acordou',
#                               'as as chances que ele merecia? Ele mancha a nossa reputação e, você sabe, ele',
#                               'noticiário noturno. “E, por último, os observadores de pássaros em toda parte registraram que as',
#                               '— CAPÍTULO QUATRO — O guardião das chaves B um. Bateram outra vez. Duda acordou',
#                               'as as chances que ele merecia? Ele mancha a nossa reputação e, você sabe, ele',
#                               'ouvidos para os ruídos lá fora, tentando identificar se os representantes do Ministério estariam chegando,',
#                               'depressa. – Está com uma cara ótima, Molly – disse Lupin, servindo uma concha do'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([14.06117403, 13.92870467, 14.5771858 , 14.06117403, 13.92870467,
#                            14.5771858 , 15.13886713, 12.76654589]),
#                'y': array([3.71131772, 2.59753267, 2.91533384, 3.71131772, 2.59753267, 2.91533384,
#                            3.4810327 , 1.90500503])},
#               {'marker': {'color': 'rgb(247,129,191)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 6',
#                'text': array(['– B-be-co Diagonal – tossiu. A sensação era de que estava sendo sugado por um',
#                               'inha começado a comer o mingau quando, a confirmar o comentário, ouviu-se um rumorejo de',
#                               'que ela podia estar se afastando para o alto? Seria um fantasma, para quem tetos',
#                               'ar, seguido de uma bruxa meio esverdeada e embrulhada em uma capa de viagem. –',
#                               's invisíveis no Beco Diagonal. Viu de relance o seu reflexo no espelho acima da',
#                               '– exclamou Fred, empurrando Percy com os cotovelos e fazendo uma grande',
#                               'matar lobisomens. Quero dois rolos de pergaminho sobre o assunto e quero para segunda-',
#                               'r terem deixado o conforto de sua lareira, quando a cozinheira dos Riddle apareceu teatralmente',
#                               'inocente e que a única pessoa que ele vira perto da casa, no dia da',
#                               'da Casa dos Riddle nem morava lá nem dava um destino à casa;',
#                               'diziam no povoado que ele a mantinha por “causa dos impostos”, embora ninguém entendesse muito',
#                               'corredor, e quando se aproximou da nesga de luz, ele percebeu, com um choque de',
#                               '– Lorde é? Ora, não tenho muito respeito pelos seus modos, milorde . Vire-se e',
#                               'Experimentais, já usa aqueles chifres há algum tempo... Alô, Arnaldinho... Arnaldo Peasegood, ele é um',
#                               'va da torcida irlandesa, e o silvo longo e agudo do apito de Mostafa informou',
#                               '— CAPÍTULO UM — O outro ministro E ra quase meia-noite e o primeiro-ministro estava',
#                               'sível, ou assim esperava, um clarão de chamas muito verdes apareceu na abertura sob o',
#                               '— CAPÍTULO DOIS — A rua da fiação A muitos quilômetros de distância, a névoa',
#                               'prende, um simples Feitiço Paralisante nesses absurdos alarmes que usam em vez de bisbilhoscópios garante',
#                               'Ah, desgraça inerente à raça! o grito torturante da morte e o golpe que atinge',
#                               'gargalhadas. – Nós, Narcisa e eu, nunca mais pusemos os olhos em nossa irmã depois',
#                               '. Tio Válter foi até a lareira e voltou, respirando com tanta força que ondulava',
#                               'gura aqui preparando vol-au-vents ? Ele falara sem pensar e notou que o rosto de',
#                               'agomir Gorgovitch, o artilheiro, teve o passe comprado pelo Chudley Cannons há dois anos por'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([7.62964276, 9.50491016, 9.17213916, 8.42167972, 9.93120993, 7.97768955,
#                            8.19202083, 8.28235885, 7.44963887, 8.52181111, 8.64583984, 8.84407326,
#                            9.40927989, 9.2074684 , 9.33795637, 8.48791727, 7.81638953, 9.09140082,
#                            8.32697668, 8.58689791, 9.29141308, 9.41997377, 7.63878483, 9.20416186]),
#                'y': array([15.46078466, 13.45125586, 12.33435159, 11.67171761, 14.84732911,
#                            15.11778141, 14.91746104, 11.70131183, 13.3421173 , 15.81557701,
#                            12.41437658, 14.55233533, 13.332358  , 13.45081101, 16.48984597,
#                            13.52646057, 12.6598013 , 15.62298562, 15.92251583, 13.23892833,
#                            14.39754418, 15.99689824, 13.344049  , 12.00489952])},
#               {'marker': {'color': 'rgb(153,153,153)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 7',
#                'text': array(['ou Murta, as lágrimas agora escorrendo livremente pelo rosto, enquanto Pirraça, feliz, dava risadinhas por',
#                               'DADOS DE COPYRIGHT Sobre a obra: A presente obra é disponibilizada pela equipe Le Livros',
#                               'rio. =============================================== Conteúdo disponíbilizado gratuitamente por Le Livros ===============================================',
#                               'o à cabeça. – Então... este ônibus – emendou ele depressa na esperança de desviar',
#                               'ou certo de que vai compreender... Não quero você',
#                               'entura vieram zombar da minha queda? Desembainhem as espadas, seus',
#                               's, fazem uma reverência e aí esperam. Se o bicho retribuir o cumprimento, vocês podem',
#                               'o alto. Não foi nada',
#                               '=============================================== Conteúdo disponíbilizado gratuitamente por Le Livros ===============================================',
#                               'ah... do começo do ano',
#                               'DADOS DE COPYRIGHT Sobre a obra: A presente obra é disponibilizada pela equipe Le Livros',
#                               'cordou assustado.',
#                               'dormecer na véspera. As ilustrações do livro se mexiam. Homens',
#                               'omento. Ah... é falar no demônio! Bartô!',
#                               'ão, sobrepondo-se à zoeira que agora enchia o estádio lotado falou; sua voz reboou, ecoando',
#                               'irritado. – Haveria uma semana de manchetes com a história do elfo doméstico; dele',
#                               'ando um dos bolos de',
#                               'DADOS DE COPYRIGHT Sobre a obra: A presente obra é disponibilizada pela equipe Le Livros',
#                               'uela ponte de ruir? Era um absurdo insinuarem que não estava gastando o suficiente na',
#                               'chamas verde-esmeralda e desaparecera com um barulhinho surdo. O primeiro-ministro ficara ali parado, imóvel, e',
#                               'a não comentar nada com ninguém,', 'sido deixada sobre sua casa.',
#                               'medo de ferilos. – Tome... –',
#                               'que ele apenas encolhia os ombros, continuou: – A mamãe vai dar',
#                               'o ninguém empunhando varinhas na minha loja! – apressou-se a acrescentar, porque, ao olhar em',
#                               'e o medo.', 'em ganhava', 'arry. – Mas você disse...',
#                               'DADOS DE COPYRIGHT Sobre a obra: A presente obra é disponibilizada pela equipe Le Livros',
#                               'uas futuras necessidades. Suas vestes de escola e de quadribol, caldeirão, pergaminho, penas e a',
#                               'o fim do ano de viagens, que outra tragédia se abatera sobre a família: a',
#                               'ma pequena escova de cabelos com o cabo de prata que se encontrava em cima',
#                               'monstrar é que, seja o que for que aconteça ao seu',
#                               'tufos. – Por favor, queiram se levantar! Todos obedeceram, tia Muriel resmungando audivelmente; ele acenou'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([12.54008928, 10.42259023, 11.95734637, 11.90129608, 11.42526307,
#                             9.63046932, 11.5546241 , 10.94263561,  9.66808188, 12.14150741,
#                            10.42259023, 11.63786757, 11.36849539, 11.98485723, 11.6244204 ,
#                            10.85803265, 11.81196744, 10.42259023, 11.75381989, 10.53690845,
#                            12.06738895, 12.1881092 , 11.31423009, 12.41967595, 10.71370432,
#                            10.50170973, 11.70953353, 12.85782043, 10.42259023, 12.30955098,
#                            12.15136485, 11.39758502, 11.40102966, 11.39970681]),
#                'y': array([19.57793981, 18.05678011, 18.8131684 , 18.21366026, 16.89661204,
#                            18.69374856, 18.15494802, 19.91873751, 19.71563318, 19.50078469,
#                            18.05678011, 19.88326225, 19.55723858, 16.67667759, 17.95648349,
#                            14.13483988, 19.96811645, 18.05678011, 15.49673715, 17.44798867,
#                            18.80566967, 20.25678666, 16.02875422, 17.38970554, 18.31596255,
#                            19.69414501, 17.49466613, 15.85384577, 18.05678011, 16.64258778,
#                            20.65020549, 19.35751295, 19.9182774 , 15.0854354 ])},
#               {'marker': {'color': 'rgb(228,26,28)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 8',
#                'text': array(['espelho retrovisor. Ele agora estava lendo a placa que dizia rua dos Alfeneiros – não,',
#                               'Naquela noite, Duda desfilou para a família reunida na sala de estar vestindo o uniforme',
#                               'Quando a noite caiu, a tempestade prometida desabou ao redor deles. A espuma das altas',
#                               'y ficou contente de ver, não parecia muito satisfeito com a distribuição dos lugares. –',
#                               'para o alto das mesas e se enroscou como uma serpente formando palavras. – Cada',
#                               'oou alta e fria – houve um clarão verde e Harry acordou, suado e trêmulo.',
#                               'espelho retrovisor. Ele agora estava lendo a placa que dizia rua dos Alfeneiros – não,',
#                               'Naquela noite, Duda desfilou para a família reunida na sala de estar vestindo o uniforme',
#                               'Quando a noite caiu, a tempestade prometida desabou ao redor deles. A espuma das altas',
#                               'y ficou contente de ver, não parecia muito satisfeito com a distribuição dos lugares. –',
#                               'para o alto das mesas e se enroscou como uma serpente formando palavras. – Cada',
#                               'oou alta e fria – houve um clarão verde e Harry acordou, suado e trêmulo.',
#                               'tentava levantar apoiado nas mãos e nos joelhos, apalpando freneticamente a escuridão. Ele ouviu Duda',
#                               'bros e continuou, lenta e penosamente, em direção à entrada de casa. A luz do',
#                               'erguendo a varinha. – Lupin disse que você tem uma Capa da Invisibilidade, mas ela',
#                               'tensamente ruivos quanto Rony, embora mais fortes e um pouco mais baixos. – Olá, Harry',
#                               'coisas que não ouvimos. Mas Molly acha que convidá-lo para jantar já é ir longe',
#                               'ma decisão dos seus pais. Por outro lado, o Harry… – Não cabe a você'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([13.30680994, 12.4989561 , 12.39830552, 14.0784948 , 11.52836656,
#                            12.53487241, 13.30680994, 12.4989561 , 12.38470033, 14.0784948 ,
#                            11.52836656, 12.53487241, 12.74164058, 13.42180864, 12.37923264,
#                            13.76916516, 13.15267941, 12.1120042 ]),
#                'y': array([ 1.08850825, -1.97084144, -1.84283005,  0.19545457, -1.30828096,
#                            -1.01529311,  1.08850825, -1.97084144, -1.85009457,  0.19545457,
#                            -1.30828096, -1.01529311, -1.51170875, -0.6178138 , -1.4432949 ,
#                            -0.79625253, -2.11715227, -1.54483588])},
#               {'marker': {'color': 'rgb(55,126,184)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 9',
#                'text': array(['divertido! E mergulhou repentinamente contra eles. Todos se abaixaram. – Vá embora, Pirraça, ou vou',
#                               'sorrateiro por trás, invisível, e agarrava-as pelo nariz e guinchava: “P EGUEI-A PELA BICANCA !”',
#                               'Excelente, Duda – disse tio Válter. Em seguida dirigiu-se zangado a Harry. – E você',
#                               'as de portas e passos no jardim. – Atenda a porta! – sibilou tia Petúnia',
#                               'o caso desse moleque. Talvez tio Válter estivesse preocupado que Harry pudesse esquecer o acordo',
#                               'tensa. Duda chegara a levantar os olhos da torta para olhar os pais, boquiaberto. –',
#                               'divertido! E mergulhou repentinamente contra eles. Todos se abaixaram. – Vá embora, Pirraça, ou vou',
#                               'sorrateiro por trás, invisível, e agarrava-as pelo nariz e guinchava: “P EGUEI-A PELA BICANCA !”',
#                               'amos AQUI! Harry ficou pregado no chão. As cartas do Ministério, do Sr. Weasley e',
#                               'voz alta: – Então, adeus, moleque. – Ergueu o braço direito para apertar a mão',
#                               'está vindo também? – repetiu Duda. – Ora, ele... ele não quer – respondeu tio',
#                               'imentos. Depois de abrir a boca mais uma ou duas vezes, o primo mergulhou em'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([6.97402648, 7.73757218, 7.50196638, 7.26609255, 6.31522336, 8.43774437,
#                            6.97402648, 7.73757218, 6.89454778, 7.93643997, 7.36838243, 8.56987514]),
#                'y': array([-0.09956589,  0.17423508, -0.38885186,  0.16298734,  0.75835704,
#                             1.09751591, -0.09956589,  0.17423508, -0.56344688,  0.29462104,
#                             0.25128679,  0.64149377])},
#               {'marker': {'color': 'rgb(77,175,74)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 10',
#                'text': array(['Alfeneiros. Era alto, magro e muito velho, a julgar pelo prateado dos seus cabelos e',
#                               'Ladrão, você foi avisado, cuidado, pois vai encontrar mais do que procurou. – Não te',
#                               'u anunciar que iria para a Grifinória. – Hermione Granger! Hermione saiu quase correndo até',
#                               'Não gosto do jeito daquela comida da escola... – Bobagem, Petúnia, nunca passei fome quando',
#                               'voz debochada atravessou o gramado. – Eu sei que dia é hoje – cantarolou Duda,',
#                               'cabelos louros e espessos do filho. – Mamãe comprou para ele uma linda gravata-borboleta. Tio',
#                               'Alfeneiros. Era alto, magro e muito velho, a julgar pelo prateado dos seus cabelos e',
#                               'Ladrão, você foi avisado, cuidado, pois vai encontrar mais do que procurou. – Não te',
#                               'u anunciar que iria para a Grifinória. – Hermione Granger! Hermione saiu quase correndo até',
#                               'chegado, não sei quanto tempo demora o correio dos trouxas. Pensei em lhe mandar este',
#                               'y não suportou a tensão: saiu da sala e foi se sentar na escada do',
#                               'as de lixo logo à entrada do portão quebrado. – Tome – murmurou Moody, empurrando'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([4.14088661, 4.73368402, 5.18518835, 4.45837358, 5.77302922, 4.87309293,
#                            4.14088661, 4.73368402, 5.18518835, 4.69147628, 5.46639175, 3.75421941]),
#                'y': array([-1.34572189, -2.0677404 , -1.09353503, -2.03768887, -1.27063375,
#                            -0.73037557, -1.34572189, -2.0677404 , -1.09353503, -1.2158798 ,
#                            -0.2166993 , -2.40699243])},
#               {'marker': {'color': 'rgb(152,78,163)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 11',
#                'text': array(['oito centímetros. Flexível. Um pouco mais de poder e excelente para transformações. Bom, digo que',
#                               'oito centímetros. Flexível. Um pouco mais de poder e excelente para transformações. Bom, digo que',
#                               'Um vulto altaneiro, encapuzado, deslizava em sua direção, flutuando sobre o solo, sem pés nem',
#                               'no chão, os braços cruzados sobre o rosto. Um segundo dementador agachava-se para ele, agarrando',
#                               'ura da bruxa. – Precisamos ganhar mais altura… subam mais quatrocentos metros! Com o frio'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([ 8.65617766,  8.65617766,  9.78298254, 10.29864203,  9.50411875]),
#                'y': array([-1.84236452, -1.84236452, -2.911767  , -2.65404288, -2.48580349])},
#               {'marker': {'color': 'rgb(255,127,0)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 12',
#                'text': array(['– Você não quer dizer, você não pode estar se referindo às pessoas que moram',
#                               '– Você não sabe... você não sabe... – Hagrid correu os dedos pelos cabelos, fixando',
#                               '– Harry Potter. – Verdade? Já ouvi falar de você, é claro. Tenho outros livros',
#                               'Rony a Harry. E examinou Perebas mais atentamente. – Não... não acredito... ele voltou a',
#                               '– Vamos chegar a Hogwarts dentro de cinco minutos. Por favor deixem a bagagem no',
#                               '– Você não sabe... você não sabe... – Hagrid correu os dedos pelos cabelos, fixando',
#                               '– Harry Potter. – Verdade? Já ouvi falar de você, é claro. Tenho outros livros',
#                               'Rony a Harry. E examinou Perebas mais atentamente. – Não... não acredito... ele voltou a',
#                               '– Vamos chegar a Hogwarts dentro de cinco minutos. Por favor deixem a bagagem no',
#                               'queria respostas, entende… – E nós queríamos dar, cara – respondeu Rony. – Hermione estava',
#                               '– Harry, nós queríamos lhe dizer, nós realmente queríamos – começou Hermione. – NÃO PODEM',
#                               'arry. Ele sabia que Voldemort matara mais de uma vez só no ano anterior. –'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([ 0.68917574, -0.40773933, -0.7232257 , -0.76223194, -1.98401715,
#                            -0.40773933, -0.71642913, -0.76223194, -1.98401715, -1.46953266,
#                            -0.1867386 , -0.44614991]),
#                'y': array([-12.49703344, -14.28081426, -14.38692586, -13.20037757, -12.94458101,
#                            -14.28081426, -14.37620253, -13.20037757, -12.94458101, -12.82686349,
#                            -12.48456065, -12.40649964])},
#               {'marker': {'color': 'rgb(255,255,51)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 13',
#                'text': array(['Na sexta-feira chegaram nada menos de doze cartas para Harry. Como não passavam pela portinhola',
#                               'parede sólida. O sol refulgia numa pilha de caldeirões à porta da loja mais próxima.',
#                               'ta vontade de alongar o assunto com esse garoto. – Ah, lamento – disse o',
#                               'vel. Apanhe e experimente. Harry apanhou a varinha e (sentindo-se bobo) fez alguns movimentos com',
#                               'um objeto nessas condições entrasse em casa. Talvez tivessem que tentar tirar um coelho de',
#                               'Na sexta-feira chegaram nada menos de doze cartas para Harry. Como não passavam pela portinhola',
#                               'parede sólida. O sol refulgia numa pilha de caldeirões à porta da loja mais próxima.',
#                               'ta vontade de alongar o assunto com esse garoto. – Ah, lamento – disse o',
#                               'vel. Apanhe e experimente. Harry apanhou a varinha e (sentindo-se bobo) fez alguns movimentos com',
#                               'um objeto nessas condições entrasse em casa. Talvez tivessem que tentar tirar um coelho de',
#                               'comida de gato. – Ai… para com isso… para com isso, sua velha caduca! Alguém',
#                               'rir a boca, mas foi-lhe poupado o trabalho de encontrar palavras pela chegada da terceira',
#                               'isita? – perguntou o tio Válter, seguindo penosamente o raciocínio de Harry. – Guardam. Se',
#                               'as quais Harry passara mais cedo, tinham se aberto, mas não havia porta alguma atrás.'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([15.19913256, 13.81411062, 14.34398493, 13.54214825, 13.48859862,
#                            15.19913256, 13.81411062, 14.34398493, 13.51506538, 13.48859862,
#                            13.56966831, 13.50465375, 12.80016491, 13.70188068]),
#                'y': array([-2.5548447 , -3.16595364, -2.51580145, -4.8444672 , -3.38815403,
#                            -2.5548447 , -3.16595364, -2.51580145, -4.85287489, -3.38815403,
#                            -4.35856078, -3.37461374, -4.79230756, -3.78077464])},
#               {'marker': {'color': 'rgb(166,86,40)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 14',
#                'text': array(['vida, não estaria em companhia de Duda. Duda tinha uma vaga na antiga escola de',
#                               'Válter, sentou-se e começou a abrir lentamente o envelope amarelo. Tio Válter rasgou o envelope',
#                               'elado; havia uma grande gaiola de pássaros, antigamente habitada por um papagaio que Duda trocara',
#                               'ia do hotel aproximou-se da mesa. – Com licença, mas um dos senhores é o',
#                               'dos. – Não poderia preparar uma xícara de chá para nós, poderia? Não foi uma',
#                               'viu-se a voz fina de uma menininha, também de cabelos ruivos que estava segurando a',
#                               'ito o que aprender... aposto – acrescentou, pondo pela primeira vez em palavras algo que',
#                               '– mas a mulher não tinha barrinhas. Tinha feijõezinhos de todos os sabores, balas de',
#                               'vida, não estaria em companhia de Duda. Duda tinha uma vaga na antiga escola de',
#                               'Válter, sentou-se e começou a abrir lentamente o envelope amarelo. Tio Válter rasgou o envelope',
#                               'elado; havia uma grande gaiola de pássaros, antigamente habitada por um papagaio que Duda trocara',
#                               'ia do hotel aproximou-se da mesa. – Com licença, mas um dos senhores é o',
#                               'dos. – Não poderia preparar uma xícara de chá para nós, poderia? Não foi uma',
#                               'viu-se a voz fina de uma menininha, também de cabelos ruivos que estava segurando a',
#                               'ito o que aprender... aposto – acrescentou, pondo pela primeira vez em palavras algo que',
#                               '– mas a mulher não tinha barrinhas. Tinha feijõezinhos de todos os sabores, balas de',
#                               'Tia Petúnia deixou escapar um gritinho. – A alma de Duda? Eles não tiraram… ele',
#                               'e voou até tia Petúnia, que deixou escapar um berro e se abaixou protegendo o',
#                               'rosto nas mãos. A carta se consumiu silenciosamente e só restaram cinzas. – Que foi'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([15.72984685, 16.17280588, 15.17605857, 15.44830842, 14.7910477 ,
#                            14.84096826, 15.7106419 , 15.11167907, 15.72984685, 16.17280588,
#                            15.17605857, 15.44830842, 14.7910477 , 14.84096826, 15.7106419 ,
#                            15.11167907, 15.68816057, 15.87427875, 15.87485775]),
#                'y': array([-5.35380802, -5.33260086, -4.19427931, -5.8098657 , -4.84376944,
#                            -4.46035051, -4.65061844, -5.33760678, -5.35380802, -5.33260086,
#                            -4.19427931, -5.8098657 , -4.84376944, -4.46035051, -4.65061844,
#                            -5.33760678, -3.36475171, -5.89712957, -4.04482591])},
#               {'marker': {'color': 'rgb(247,129,191)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 15',
#                'text': array(['– Eu não sou Fred, sou Jorge – retrucou o menino. – Francamente, mulher, você',
#                               'ajuda dos gêmeos, a mala de Harry finalmente foi colocada a um canto do compartimento.',
#                               '– Ele vai aparecer – consolou Harry. – Vai – disse o menino, infeliz. –',
#                               '– Eu não sou Fred, sou Jorge – retrucou o menino. – Francamente, mulher, você',
#                               'ajuda dos gêmeos, a mala de Harry finalmente foi colocada a um canto do compartimento.',
#                               '– Ele vai aparecer – consolou Harry. – Vai – disse o menino, infeliz. –'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([8.08791556, 7.21998216, 7.12832456, 8.08791556, 7.21998216, 7.12832456]),
#                'y': array([-12.1832364 , -12.24927393, -12.5191723 , -12.1832364 , -12.24927393,
#                            -12.5191723 ])},
#               {'marker': {'color': 'rgb(153,153,153)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 16',
#                'text': array(['caso saiu errado. Queria transformá-lo em porco, mas acho que ele já parecia tanto com',
#                               'caso saiu errado. Queria transformá-lo em porco, mas acho que ele já parecia tanto com',
#                               'e Hermione estavam ocupados? Por que ele, Harry, não estava ocupado? Não se mostrara capaz',
#                               '– Ahh! Eles vieram prender você! – disse o tio, com o ar triunfante de',
#                               'Harry; os cantos de sua boca mexeram ligeiramente. – Ah, foi, quanto mais melhor –',
#                               '– Que aconteceu? – perguntou Harry. – Percy e papai brigaram – contou Fred. –',
#                               'ou Harry depressa. – Entro para a Ordem, quero entrar, quero lutar. – Não. Não'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([2.1944108 , 2.1944108 , 2.54011995, 2.16604465, 1.57778512, 1.07343827,
#                            2.24998162]),
#                'y': array([-13.24135486, -13.24135486, -13.59198769, -12.96417013, -13.46267048,
#                            -13.25172931, -13.20941778])},
#               {'marker': {'color': 'rgb(228,26,28)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 17',
#                'text': array(['— CAPÍTULO UM — O menino que sobreviveu O Sr. e a Sra. Dursley, da',
#                               'ficou paralisado na poltrona. Estrelas cadentes em todo o país? Corujas voando durante o dia?',
#                               'tava brancoesverdeado. Harry cruzou os dedos sob a mesa para dar sorte e um segundo',
#                               '— CAPÍTULO UM — O menino que sobreviveu O Sr. e a Sra. Dursley, da',
#                               'ficou paralisado na poltrona. Estrelas cadentes em todo o país? Corujas voando durante o dia?',
#                               'tava brancoesverdeado. Harry cruzou os dedos sob a mesa para dar sorte e um segundo',
#                               'riedade de objetos: uma coleção de adagas enferrujadas, garras, uma pele de cobra enrolada, algumas'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([5.97547402, 5.9622554 , 5.2628272 , 5.97547402, 5.9622554 , 5.2628272 ,
#                            6.43601877]),
#                'y': array([-3.74345427, -3.43919793, -3.48759019, -3.74345427, -3.43919793,
#                            -3.48759019, -2.92668259])},
#               {'marker': {'color': 'rgb(55,126,184)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 18',
#                'text': array(['ados do que o normal, olhando, nervosos, para os lados. – Bem-vindos a Hogwarts –',
#                               '– A Transfiguração é uma das mágicas mais complexas e perigosas que vão aprender em',
#                               ', contou ele, fora presente de um príncipe africano como agradecimento por tê-lo livrado de',
#                               'ados do que o normal, olhando, nervosos, para os lados. – Bem-vindos a Hogwarts –',
#                               '– A Transfiguração é uma das mágicas mais complexas e perigosas que vão aprender em',
#                               ', contou ele, fora presente de um príncipe africano como agradecimento por tê-lo livrado de',
#                               'que Voldemort voltara? Esses pensamentos indignados giravam em sua cabeça, e suas entranhas se contorciam',
#                               'pudessem descer a escada… – Calma aí! – sussurrou Rony, esticando um braço para impedir'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([0.85686084, 1.27202839, 0.71234643, 0.85686084, 1.27202839, 0.73217432,
#                            0.92396189, 1.47666921]),
#                'y': array([-6.23070942, -5.48046513, -6.047273  , -6.23070942, -5.48046513,
#                            -6.04080969, -5.74188323, -6.40071914])},
#               {'marker': {'color': 'rgb(77,175,74)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 19',
#                'text': array(['Duda parecia um anjinho – Harry dizia com frequência que Duda parecia um porco de',
#                               'oi Pedro ter se acalmado o suficiente para perguntar: – Harry estava conversando com ela,',
#                               'penoso. – Hum, sim, Harry, sobre este armário. Sua tia e eu estivemos pensando... você',
# ...
#                               'dos ficaram realmente satisfeitos. Minha avó chorou de tanta felicidade. E vocês deviam ter visto',
#                               's dois do caminho. Só o que sabemos é que ele apareceu na vila em',
#                               'os trouxas conseguem se arranjar sem mágica – disse, quando subiam uma escada rolante gasta',
#                               'murado, onde não havia nada exceto uma lata de lixo e um pouco de mato.',
#                               'a fechada – recomendou Hagrid. Depois de mais uma viagem no vagonete descontrolado, eles chegaram',
#                               'senhor me desculpe – disse Harry –, mas o que é curioso? O Sr. Olivaras',
#                               '– Tenha um bom período letivo – disse tio Válter com um sorriso ainda mais',
#                               'dos ficaram realmente satisfeitos. Minha avó chorou de tanta felicidade. E vocês deviam ter visto',
#                               '– Eu tenho uma coruja, posso lhe emprestar. – Harry gemeu, receando que sua coluna',
#                               've de enfrentar tanto quanto a maioria dos participantes da Ordem e mais do que'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([3.89178275, 4.69151083, 4.64308655, 3.89989326, 4.59079922, 4.3482356 ,
#                            5.0815665 , 3.89178275, 4.69151083, 4.64308655, 3.89989326, 4.59079922,
#                            4.3482356 , 5.0815665 , 4.28052449, 4.51846922]),
#                'y': array([-11.01408813, -10.71758929, -10.68261937, -11.38954646, -11.38299612,
#                            -11.72714368, -10.8518342 , -11.01408813, -10.71758929, -10.68261937,
#                            -11.38954646, -11.38299612, -11.72714368, -10.8518342 , -11.72703107,
#                            -11.09810802])},
#               {'marker': {'color': 'rgb(255,127,0)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 39',
#                'text': array(['coruja mesmo à noite. O Sr. Dursley, porém, teve uma manhã perfeitamente normal sem corujas.',
#                               'eixou cair o jornal em cima de Hagrid, que nem acordou. A coruja então voou',
#                               'coruja mesmo à noite. O Sr. Dursley, porém, teve uma manhã perfeitamente normal sem corujas.',
#                               'eixou cair o jornal em cima de Hagrid, que nem acordou. A coruja então voou',
#                               'luiu Lupin. – Você também iria preferir se a tonta da sua mãe tivesse lhe',
#                               'Ele ouviu um assobio suave e em seguida candeeiros antiquados, a gás, ganharam vida ao',
#                               'sentiu uma repentina afeição pelo padrinho. – Pelo menos você acompanhou o que estava acontecendo',
#                               'Craque . – AI! – Fale baixo, Rony, ou mamãe volta já, já aqui. –'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([5.81262847, 6.63160662, 5.81262847, 6.63160662, 5.76611341, 6.16210667,
#                            5.7463156 , 5.67231836]),
#                'y': array([-5.85825844, -5.74796955, -5.85825844, -5.74796955, -6.03765728,
#                            -6.02668752, -5.9516646 , -6.1558775 ])},
#               {'marker': {'color': 'rgb(255,255,51)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 40',
#                'text': array(['Nenhum deles reparou em uma coruja parda que passou, batendo as asas, pela janela. Às',
#                               'horando. Meia hora depois, Harry, que não conseguia acreditar em sua sorte, estava sentado no',
#                               'Harry sentou-se e parou de respirar: o vidro da frente do tanque da jiboia tinha',
#                               'direção. Eles embarcaram – Hagrid com alguma dificuldade – e partiram. A princípio eles apenas',
#                               'Olivaras estava esperando. A pilha de varinhas experimentadas estava cada vez maior em cima da',
#                               'e aconteceu com eles? – Nada, é por isso que é uma notícia tão importante.',
#                               'Nenhum deles reparou em uma coruja parda que passou, batendo as asas, pela janela. Às',
#                               'horando. Meia hora depois, Harry, que não conseguia acreditar em sua sorte, estava sentado no',
#                               'Harry sentou-se e parou de respirar: o vidro da frente do tanque da jiboia tinha',
#                               'direção. Eles embarcaram – Hagrid com alguma dificuldade – e partiram. A princípio eles apenas',
#                               'Olivaras estava esperando. A pilha de varinhas experimentadas estava cada vez maior em cima da',
#                               'e aconteceu com eles? – Nada, é por isso que é uma notícia tão importante.',
#                               'rtância quando lhe escrevêssemos, disse que as corujas poderiam ser interceptadas. – Ainda assim, ele'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([6.14716494, 5.97438104, 5.77268147, 6.98692764, 6.35711783, 5.52272939,
#                            6.14716494, 5.97438104, 5.77268147, 6.98692764, 6.35711783, 5.52272939,
#                            6.76430284]),
#                'y': array([-5.38642287, -4.95300485, -4.74015878, -5.5352806 , -5.20517094,
#                            -4.79070766, -5.38642287, -4.95300485, -4.74015878, -5.5352806 ,
#                            -5.20517094, -4.79070766, -5.15095792])},
#               {'marker': {'color': 'rgb(166,86,40)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 41',
#                'text': array(['devagarinho no batente, tirou uma carta da capa, meteu-a entre os cobertores do menino e,',
#                               'Teoria da magia de Adalberto Waffling Guia de transfiguração para iniciantes de Emerico Switch Mil',
#                               'devagarinho no batente, tirou uma carta da capa, meteu-a entre os cobertores do menino e,',
#                               'Teoria da magia de Adalberto Waffling Guia de transfiguração para iniciantes de Emerico Switch Mil',
#                               'imar de raiva. – Quem é Monstro? – perguntou. – O elfo doméstico que mora'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([6.22615483, 6.08089235, 6.22615483, 6.08089235, 5.65723668]),
#                'y': array([-8.24431069, -8.40069561, -8.24431069, -8.40069561, -8.05714984])},
#               {'marker': {'color': 'rgb(247,129,191)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 42',
#                'text': array(['ilômetros abaixo, entenda. Mais fundo que o metrô. Você morreria de fome tentando sair de',
#                               'elo turbante de Quirrell e se fixou nos olhos de Harry, e uma pontada aguda',
#                               'ilômetros abaixo, entenda. Mais fundo que o metrô. Você morreria de fome tentando sair de',
#                               'elo turbante de Quirrell e se fixou nos olhos de Harry, e uma pontada aguda',
#                               'o que Harry reconheceu na mesma hora como uma Capa da Invisibilidade. – Alguma novidade,',
#                               'casas. – Onde estamos? – perguntou Harry, mas Lupin disse baixinho: – Em um instante.',
#                               'edir desculpas, repondo a pesada perna de trasgo na posição original; a Sra. Weasley desistiu',
#                               'o professor de Trato das Criaturas Mágicas, ia dizendo “ Umas lindezas, não são? Este'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([3.98563819, 3.47798036, 3.96749027, 3.47798036, 3.53461116, 3.84677444,
#                            4.15116398, 3.4436475 ]),
#                'y': array([-7.87564174, -7.82396312, -7.8936793 , -7.82396312, -8.15473693,
#                            -7.64220043, -7.41820698, -8.32018668])},
#               {'marker': {'color': 'rgb(153,153,153)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 43',
#                'text': array(['— CAPÍTULO SEIS — O embarque na plataforma nove e meia O último mês de',
#                               'Harry empurrou o carrinho pela plataforma procurando um lugar vago. Passou por um garoto de',
#                               'les pareciam guarda-costas. – Ah, este é Crabbe e este outro, Goyle – apresentou o',
#                               'mas e deram vivas. Harry não sabia se ria ou não. – Ele é... um',
#                               '— CAPÍTULO SEIS — O embarque na plataforma nove e meia O último mês de',
#                               'Harry empurrou o carrinho pela plataforma procurando um lugar vago. Passou por um garoto de',
#                               'les pareciam guarda-costas. – Ah, este é Crabbe e este outro, Goyle – apresentou o',
#                               'mas e deram vivas. Harry não sabia se ria ou não. – Ele é... um',
#                               '— CAPÍTULO DOIS — Uma revoada de corujas – Q uê? – exclamou Harry sem',
#                               'as por sorte eu tinha mandado o Sr. Tibbles ficar debaixo de um carro, só',
#                               'de gato em todas as partes do corpo de Mundungo ao seu alcance. – E…',
#                               'Durante todo esse alvoroço, ninguém pareceu ter reparado em Harry, o que lhe convinha perfeitamente.'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([5.39819339, 5.21519809, 5.2643054 , 5.51345587, 5.39819339, 5.21519809,
#                            5.2643054 , 5.51345587, 5.15728148, 4.80677412, 5.45478487, 5.64676957]),
#                'y': array([-8.81654906, -9.44756556, -9.30587741, -8.65805052, -8.81654906,
#                            -9.44756556, -9.30587741, -8.65805052, -8.7615193 , -8.71052468,
#                            -9.13680742, -9.2744586 ])},
#               {'marker': {'color': 'rgb(228,26,28)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 44',
#                'text': array(['s nenhum número; em vez deles, pequenos planetas giravam à volta. Mas devia fazer sentido',
#                               'dore, olhando muito sério por cima dos óculos de meia-lua. – Isto seria o bastante',
#                               'jornal e eles subiram os degraus de pedra que levavam à rua. As pessoas que',
#                               'quando o vagonete afinal parou ao lado de uma portinhola na passagem, Hagrid saltou e',
#                               'stou na Lufa-Lufa – disse Harry deprimido. – É melhor a Lufa-Lufa do que a',
#                               'segundo grau que é contador, mas ninguém nunca fala nele. – Então você já deve',
#                               'que vivia perdendo o sapo, fungou umas duas vezes. – Vocês vão ter a primeira',
#                               's nenhum número; em vez deles, pequenos planetas giravam à volta. Mas devia fazer sentido',
#                               'dore, olhando muito sério por cima dos óculos de meia-lua. – Isto seria o bastante',
#                               'jornal e eles subiram os degraus de pedra que levavam à rua. As pessoas que',
#                               'quando o vagonete afinal parou ao lado de uma portinhola na passagem, Hagrid saltou e',
#                               'stou na Lufa-Lufa – disse Harry deprimido. – É melhor a Lufa-Lufa do que a',
#                               'segundo grau que é contador, mas ninguém nunca fala nele. – Então você já deve',
#                               'que vivia perdendo o sapo, fungou umas duas vezes. – Vocês vão ter a primeira',
#                               'abretes. – Então – ofegou Harry – Dumbledore… mandou… gente me seguir? – É claro',
#                               'Seção de Controle do Uso Indevido de Magia Ministério da Magia Harry leu esta carta',
#                               'O bruxo deu uma pancada forte no cocuruto de Harry e ele teve a curiosa',
#                               'nua na Romênia. Dumbledore quer atrair o maior número possível de bruxos estrangeiros, por isso',
#                               'pertencido a Duda). Quando ele finalmente descansou a colher, tinha havido uma pausa na conversa',
#                               '— CAPÍTULO SEIS — A mui antiga e nobre casa dos Black A Sra. Weasley'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([3.28270504, 2.9974779 , 3.97748455, 3.06143993, 3.68719205, 3.3237662 ,
#                            2.870954  , 3.28270504, 2.9974779 , 3.9643912 , 3.06143993, 3.68719205,
#                            3.3237662 , 2.870954  , 3.10306696, 3.17682804, 3.16019167, 3.48530595,
#                            3.35975425, 2.71616219]),
#                'y': array([-9.35887843, -9.50711976, -9.33401728, -9.40040767, -9.10757693,
#                            -9.72316821, -9.33913949, -9.35887843, -9.50711976, -9.30113539,
#                            -9.40040767, -9.10757693, -9.72316821, -9.33913949, -9.43378636,
#                            -9.36984238, -9.33956665, -8.99665653, -9.40845965, -9.8815408 ])},
#               {'marker': {'color': 'rgb(55,126,184)', 'line': {'color': 'DarkSlateGrey', 'width': 1}, 'size': 8},
#                'mode': 'markers',
#                'name': 'Cluster 45',
#                'text': array(['todos estão dizendo? Por que ele foi embora? Que foi que finalmente o deteve? Aparentemente',
#                               'futebol? – Rúbeo – disse calmo –, acho que você deve ter cometido um engano.',
#                               'Era um barzinho sujo. Se Hagrid não o tivesse apontado, Harry nem teria reparado que',
#                               'todos estão dizendo? Por que ele foi embora? Que foi que finalmente o deteve? Aparentemente',
#                               'futebol? – Rúbeo – disse calmo –, acho que você deve ter cometido um engano.',
#                               'Era um barzinho sujo. Se Hagrid não o tivesse apontado, Harry nem teria reparado que',
#                               'intrigada de Harry no espelho às suas costas. – Nasci assim. Recebia as melhores notas',
#                               'tinha deixado na chefia, e ele não ia reclamar. – Então como foi que ganhou',
#                               'ongada que lembrava o nariz do Snape, encolheu e se arredondou como um champignon e',
#                               'com a língua nos dentes – disse Sirius –, e é muito importante para nós',
#                               'sugeriu Jorge. – Talvez seja algum modo bem doloroso de matar gente – disse Rony,'],
#                              dtype=object),
#                'type': 'scatter',
#                'x': array([1.18429889, 1.70424777, 2.05459206, 1.18429889, 1.70424777, 2.05459206,
#                            2.26983415, 1.67691751, 2.30741731, 2.30149313, 1.35950478]),
#                'y': array([ -9.82333452, -10.08097329,  -9.84989448,  -9.82333452, -10.08097329,
#                             -9.84989448,  -9.83580482, -10.08675281,  -9.89834443,  -9.76844532,
#                             -9.8947791 ])}],
#      'layout': {'legend': {'title': {'text': 'Cluster'}},
#                 'template': '...',
#                 'title': {'text': 'PCA of Book Embeddings with HDBSCAN Clusters'},
#                 'xaxis': {'title': {'text': 'Principal Component 1'}},
#                 'yaxis': {'title': {'text': 'Principal Component 2'}}}
#  }),
#  HDBSCAN(gen_min_span_tree=True),
#  StandardScaler())
